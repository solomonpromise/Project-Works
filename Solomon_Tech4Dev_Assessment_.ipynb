# %% [markdown]
# <a href="https://colab.research.google.com/github/solomonpromise/Project-Works/blob/master/Solomon_Tech4Dev_Assessment_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # World Happiness Analysis

# %% [markdown]
# This work seeks to is to measure global happiness using the following variables: `life expectancy`, `economics`, `social support`, `absence of corruption`, `freedom`, and `generosity`.
#
# The datasets used for this work is the World Happiness Report for the years 2015, 2016, 2017, 2018, and 2019, with which we seek to answer the following questions:
#
# 1. Which country is the happiest in the world?
# 2. What are the most important contributing factors to a nation’s happiness?
# 3. Is overall happiness increasing or decreasing?

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading in files

# %%
year_2015 = pd.read_csv("2015.csv")
year_2016 = pd.read_csv("2016.csv")
year_2017 = pd.read_csv("2017.csv")
year_2018 = pd.read_csv("2018.csv")
year_2019 = pd.read_csv("2019.csv")

# %% [markdown]
# ### Year 2015

# %%
year_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
## Preparing year 2015 dataset for us

usecols = ['Rank','Country','Score','GDP','Support',
                'Health','Freedom','Generosity','Corruption']


year_2015.drop(['Region','Standard Error', 'Dystopia Residual'],axis=1,inplace=True)
#droping irrelevant columns

year_2015.columns = ['Country','Rank','Score','Support',
                'GDP','Health',
                'Freedom','Generosity','Corruption']
#remaining column names

year_2015['Year'] = 2015 #add year column
year_2015.head()
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0  Switzerland     1  7.587  1.39651  1.34951  0.94143  0.66557     0.41978
# 1      Iceland     2  7.561  1.30232  1.40223  0.94784  0.62877     0.14145
# 2      Denmark     3  7.527  1.32548  1.36058  0.87464  0.64938     0.48357
# 3       Norway     4  7.522  1.45900  1.33095  0.88521  0.66973     0.36503
# 4       Canada     5  7.427  1.32629  1.32261  0.90563  0.63297     0.32957
#
#    Corruption  Year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015

# %% [markdown]
# ### Year 2016

# %%
year_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
#Preparaing the data for use

year_2016.drop(['Region','Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'],axis=1,inplace=True)
year_2016.columns = ['Country','Rank','Score','Support',
                'GDP','Health',
                'Freedom','Generosity','Corruption']
year_2016['Year'] = 2016 #add year column
year_2016.head()
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0      Denmark     1  7.526  1.44178  1.16374  0.79504  0.57941     0.44453
# 1  Switzerland     2  7.509  1.52733  1.14524  0.86303  0.58557     0.41203
# 2      Iceland     3  7.501  1.42666  1.18326  0.86733  0.56624     0.14975
# 3       Norway     4  7.498  1.57744  1.12690  0.79579  0.59609     0.35776
# 4      Finland     5  7.413  1.40598  1.13464  0.81091  0.57104     0.41004
#
#    Corruption  Year
# 0     0.36171  2016
# 1     0.28083  2016
# 2     0.47678  2016
# 3     0.37895  2016
# 4     0.25492  2016

# %% [markdown]
# ### Year 2017

# %%
year_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
## Data Prearation for year 2017

year_2017.drop(['Whisker.high', 'Whisker.low', 'Dystopia.Residual'], axis = 1, inplace = True)
year_2017.columns = ['Country','Rank','Score',
                'GDP','Support','Health',
                'Freedom','Generosity','Corruption']
year_2017['Year'] = 2017 #add year column
year_2017.head()
# Out:
#        Country  Rank  Score       GDP   Support    Health   Freedom  \
# 0       Norway     1  7.537  1.616463  1.533524  0.796667  0.635423
# 1      Denmark     2  7.522  1.482383  1.551122  0.792566  0.626007
# 2      Iceland     3  7.504  1.480633  1.610574  0.833552  0.627163
# 3  Switzerland     4  7.494  1.564980  1.516912  0.858131  0.620071
# 4      Finland     5  7.469  1.443572  1.540247  0.809158  0.617951
#
#    Generosity  Corruption  Year
# 0    0.362012    0.315964  2017
# 1    0.355280    0.400770  2017
# 2    0.475540    0.153527  2017
# 3    0.290549    0.367007  2017
# 4    0.245483    0.382612  2017

# %% [markdown]
# ## Year 2018

# %%
year_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
year_2018.columns = ['Rank','Country','Score',
                'GDP','Support','Health',
                'Freedom','Generosity','Corruption']
year_2018['Year'] = 2018 #add year column
year_2018.head()
# Out:
#    Rank      Country  Score    GDP  Support  Health  Freedom  Generosity  \
# 0     1      Finland  7.632  1.305    1.592   0.874    0.681       0.202
# 1     2       Norway  7.594  1.456    1.582   0.861    0.686       0.286
# 2     3      Denmark  7.555  1.351    1.590   0.868    0.683       0.284
# 3     4      Iceland  7.495  1.343    1.644   0.914    0.677       0.353
# 4     5  Switzerland  7.487  1.420    1.549   0.927    0.660       0.256
#
#    Corruption  Year
# 0       0.393  2018
# 1       0.340  2018
# 2       0.408  2018
# 3       0.138  2018
# 4       0.357  2018

# %% [markdown]
# ### Year 2019

# %%
year_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
year_2019.columns = ['Rank','Country','Score',
                'GDP','Support','Health',
                'Freedom','Generosity','Corruption']
year_2019['Year'] = 2019 #add year column
year_2019.head()
# Out:
#    Rank      Country  Score    GDP  Support  Health  Freedom  Generosity  \
# 0     1      Finland  7.769  1.340    1.587   0.986    0.596       0.153
# 1     2      Denmark  7.600  1.383    1.573   0.996    0.592       0.252
# 2     3       Norway  7.554  1.488    1.582   1.028    0.603       0.271
# 3     4      Iceland  7.494  1.380    1.624   1.026    0.591       0.354
# 4     5  Netherlands  7.488  1.396    1.522   0.999    0.557       0.322
#
#    Corruption  Year
# 0       0.393  2019
# 1       0.410  2019
# 2       0.341  2019
# 3       0.118  2019
# 4       0.298  2019

# %% [markdown]
# ### Concatinig the Prepared datasets

# %%
df = pd.concat([year_2015, year_2016, year_2017, year_2018, year_2019])
df.sample(10)
# Out:
#          Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 90       Nigeria    91  5.155  1.17200  0.68900  0.04800  0.46200     0.20100
# 136        Egypt   137  4.166  1.03900  0.91300  0.64400  0.24100     0.07600
# 86    Azerbaijan    87  5.201  1.16100  1.02400  0.60300  0.43000     0.03100
# 36         Malta    37  6.302  1.20740  1.30203  0.88721  0.60365     0.13586
# 96        Bhutan    97  5.082  1.33500  0.79600  0.52700  0.54100     0.36400
# 84    Kyrgyzstan    85  5.185  0.56044  0.95434  0.55449  0.40212     0.04762
# 31         Qatar    32  6.374  1.30300  1.64900  0.74800  0.65400     0.25600
# 152  Afghanistan   153  3.575  0.31982  0.30285  0.30335  0.23414     0.09719
# 11    Costa Rica    12  7.167  1.44100  1.03400  0.96300  0.55800     0.14400
# 115      Armenia   116  4.559  1.05500  0.85000  0.81500  0.28300     0.09500
#
#      Corruption  Year
# 90      0.03200  2018
# 136     0.06700  2019
# 86      0.17600  2018
# ...

# %% [markdown]
# ### Non Graphical/Numerical EDA on the combined dataset

# %%
#.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     782 non-null    object
#  1   Rank        782 non-null    int64
#  2   Score       782 non-null    float64
#  3   Support     782 non-null    float64
#  4   GDP         782 non-null    float64
#  5   Health      782 non-null    float64
#  6   Freedom     782 non-null    float64
#  7   Generosity  782 non-null    float64
#  8   Corruption  781 non-null    float64
#  9   Year        782 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 67.2+ KB

# %%
##Checking for missing values 
df.isna().mean()*100
# Out:
# Country       0.000000
# Rank          0.000000
# Score         0.000000
# Support       0.000000
# GDP           0.000000
# Health        0.000000
# Freedom       0.000000
# Generosity    0.000000
# Corruption    0.127877
# Year          0.000000
# dtype: float64

# %%
## dropping the missing value. 
##The percentage of the missing values is below 5% hence the essence of dropping.
## This approach is backed up by relivant authorties.

df.Corruption.fillna((df.Corruption.median()), inplace = True)
df.head(10)
# Out:
#        Country  Rank  Score  Support      GDP   Health  Freedom  Generosity  \
# 0  Switzerland     1  7.587  1.39651  1.34951  0.94143  0.66557     0.41978
# 1      Iceland     2  7.561  1.30232  1.40223  0.94784  0.62877     0.14145
# 2      Denmark     3  7.527  1.32548  1.36058  0.87464  0.64938     0.48357
# 3       Norway     4  7.522  1.45900  1.33095  0.88521  0.66973     0.36503
# 4       Canada     5  7.427  1.32629  1.32261  0.90563  0.63297     0.32957
# 5      Finland     6  7.406  1.29025  1.31826  0.88911  0.64169     0.41372
# 6  Netherlands     7  7.378  1.32944  1.28017  0.89284  0.61576     0.31814
# 7       Sweden     8  7.364  1.33171  1.28907  0.91087  0.65980     0.43844
# 8  New Zealand     9  7.286  1.25018  1.31967  0.90837  0.63938     0.42922
# 9    Australia    10  7.284  1.33358  1.30923  0.93156  0.65124     0.35637
#
#    Corruption  Year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015
# ...

# %%
## Checking the descriptive statistics of the dataset

df.describe().T
# Out:
#             count         mean        std       min          25%          50%  \
# Rank        782.0    78.698210  45.182384     1.000    40.000000    79.000000
# Score       782.0     5.379018   1.127456     2.693     4.509750     5.322000
# Support     782.0     1.081289   0.377263     0.000     0.865252     1.165460
# GDP         782.0     0.913151   0.362273     0.000     0.682000     0.960000
# Health      782.0     0.612416   0.248309     0.000     0.440183     0.647310
# Freedom     782.0     0.411091   0.152880     0.000     0.309767     0.431000
# Generosity  782.0     0.178526   0.119115     0.000     0.084860     0.155219
# Corruption  782.0     0.165488   0.127336     0.000     0.067921     0.128000
# Year        782.0  2016.993606   1.417364  2015.000  2016.000000  2017.000000
#
#                     75%          max
# Rank         118.000000   158.000000
# Score          6.189500     7.769000
# Support        1.384516     1.824270
# GDP            1.175250     2.096000
# ...

# %%
#This gives us the distribution of values from the numerical columns
df.hist(figsize=(15, 8))
plt.show()

# %%
#This gives the distribution of the Happiness Score.

fig = plt.figure(figsize=(8,6))
sns.distplot(df['Score'])
plt.title('Distribution of Score')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Score')

# %% [markdown]
# **The Score has values ranging between `2.85` and below `7.76`.**

# %% [markdown]
# ### Question 1: Which country is the happiest in the world?

# %% [markdown]
# **In an attempt to answer this question, several approaches/steps were carried out.**

# %% [markdown]
# **1.**: The combined dataset `df` was groupby `Year`, and the result of this is that the data was sorted in descending order for one year, follwed by the other. This result was stored in the variable name called `hap`.

# %%
hap = df.groupby('Year')
hap.head(5)
# Out:
#        Country  Rank  Score   Support       GDP    Health   Freedom  \
# 0  Switzerland     1  7.587  1.396510  1.349510  0.941430  0.665570
# 1      Iceland     2  7.561  1.302320  1.402230  0.947840  0.628770
# 2      Denmark     3  7.527  1.325480  1.360580  0.874640  0.649380
# 3       Norway     4  7.522  1.459000  1.330950  0.885210  0.669730
# 4       Canada     5  7.427  1.326290  1.322610  0.905630  0.632970
# 0      Denmark     1  7.526  1.441780  1.163740  0.795040  0.579410
# 1  Switzerland     2  7.509  1.527330  1.145240  0.863030  0.585570
# 2      Iceland     3  7.501  1.426660  1.183260  0.867330  0.566240
# 3       Norway     4  7.498  1.577440  1.126900  0.795790  0.596090
# 4      Finland     5  7.413  1.405980  1.134640  0.810910  0.571040
# 0       Norway     1  7.537  1.533524  1.616463  0.796667  0.635423
# 1      Denmark     2  7.522  1.551122  1.482383  0.792566  0.626007
# 2      Iceland     3  7.504  1.610574  1.480633  0.833552  0.627163
# ...

# %% [markdown]
# **2:** The head which shows the first five happiest countires for each was aftered stored into a varible name called `hap_5`. This was to allow me carry out further analysis.
#
# **Hecne the dataframe `hap_5` contains just the first five happiest countries for each year.**

# %%
hap_5 = hap.head()
hap_5
# Out:
#        Country  Rank  Score   Support       GDP    Health   Freedom  \
# 0  Switzerland     1  7.587  1.396510  1.349510  0.941430  0.665570
# 1      Iceland     2  7.561  1.302320  1.402230  0.947840  0.628770
# 2      Denmark     3  7.527  1.325480  1.360580  0.874640  0.649380
# 3       Norway     4  7.522  1.459000  1.330950  0.885210  0.669730
# 4       Canada     5  7.427  1.326290  1.322610  0.905630  0.632970
# 0      Denmark     1  7.526  1.441780  1.163740  0.795040  0.579410
# 1  Switzerland     2  7.509  1.527330  1.145240  0.863030  0.585570
# 2      Iceland     3  7.501  1.426660  1.183260  0.867330  0.566240
# 3       Norway     4  7.498  1.577440  1.126900  0.795790  0.596090
# 4      Finland     5  7.413  1.405980  1.134640  0.810910  0.571040
# 0       Norway     1  7.537  1.533524  1.616463  0.796667  0.635423
# 1      Denmark     2  7.522  1.551122  1.482383  0.792566  0.626007
# 2      Iceland     3  7.504  1.610574  1.480633  0.833552  0.627163
# ...

# %%
hap_5["Country"].unique()
# Out:
# array(['Switzerland', 'Iceland', 'Denmark', 'Norway', 'Canada', 'Finland',
#        'Netherlands'], dtype=object)

# %% [markdown]
# **3:** The `hap_5`, was sorted to find the happiest country out of the five happiest countires for each year.
#
# **After this sorting, `FINLAND` happens to be the happiest country with a score of `7.769` for the year 2019**

# %%
hap_5.sort_values("Score" , ascending=False)
# Out:
#        Country  Rank  Score   Support       GDP    Health   Freedom  \
# 0      Finland     1  7.769  1.587000  1.340000  0.986000  0.596000
# 0      Finland     1  7.632  1.592000  1.305000  0.874000  0.681000
# 1      Denmark     2  7.600  1.573000  1.383000  0.996000  0.592000
# 1       Norway     2  7.594  1.582000  1.456000  0.861000  0.686000
# 0  Switzerland     1  7.587  1.396510  1.349510  0.941430  0.665570
# 1      Iceland     2  7.561  1.302320  1.402230  0.947840  0.628770
# 2      Denmark     3  7.555  1.590000  1.351000  0.868000  0.683000
# 2       Norway     3  7.554  1.582000  1.488000  1.028000  0.603000
# 0       Norway     1  7.537  1.533524  1.616463  0.796667  0.635423
# 2      Denmark     3  7.527  1.325480  1.360580  0.874640  0.649380
# 0      Denmark     1  7.526  1.441780  1.163740  0.795040  0.579410
# 3       Norway     4  7.522  1.459000  1.330950  0.885210  0.669730
# 1      Denmark     2  7.522  1.551122  1.482383  0.792566  0.626007
# ...

# %% [markdown]
# **4:** Further Analysis was made based on the cummulative Score for the five years.
#
# **After this, `DENMARK` seems to be the happiest conntry in the world with a cummulative score of `37.730` for the five years**

# %%
hap_cum = hap_5.groupby('Country')['Score'].sum()
hap_cum
# Out:
# Country
# Canada          7.427
# Denmark        37.730
# Finland        30.283
# Iceland        37.555
# Netherlands     7.488
# Norway         37.705
# Switzerland    30.077
# Name: Score, dtype: float64

# %% [markdown]
# **5:** A dataframe was created to allow me visualize the countires with the happiest countires in the world based on their cummulative score for the five year

# %%
hap_cum = {'Country': ['Canada', 'Denmark', 'Finland', 'Iceland', 'Netherlands','Norway','Switzerland'], 'Happiness Score': [7.427, 37.730, 30.283, 37.555,7.488,37.705,30.077]}
hap_cum = pd.DataFrame(data=hap_cum)

hap_cum
# Out:
#        Country  Happiness Score
# 0       Canada            7.427
# 1      Denmark           37.730
# 2      Finland           30.283
# 3      Iceland           37.555
# 4  Netherlands            7.488
# 5       Norway           37.705
# 6  Switzerland           30.077

# %% [markdown]
# ### Visualization of top seven Happiest Countries in the World Based on their cummulative Score

# %%
fig_dims = (10, 6)

fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x = 'Country', y = 'Happiness Score', data=hap_cum)
plt.title("Top Seven Happiest Countiries in the world")
# Out:
# Text(0.5, 1.0, 'Top Seven Happiest Countiries in the world')

# %% [markdown]
# **Hence, I can say the regardless of year, `FINLAND` is the HAPPIEST COUNTIRES IN THE WORLD  with a score of `7.769`.**
#
# **But if the cumulative score of the five year is taken as the basis of consideration, then `DENMARK` is the HAPPIEST COUNTRY IN THE WORLD WITH A TOTAL SCORE OF `37.730`.**

# %% [markdown]
# ### QUESTION 2: What are the most important contributing factors to a nation’s happiness?

# %% [markdown]
# A correlation heat map can be used to answer this question becuase it shows how related the variables within a dataset is.
#
# From the correlation heat map we can tell which variables are strongly related to the Happiness Score based on there correlation coefficient.

# %%
X = df[[ 'GDP', 'Health', 'Support','Freedom','Generosity','Corruption']]
y = df['Score']

# %%
corrMatrix = df.corr()
df.corr()
# Out:
#                 Rank     Score   Support       GDP    Health   Freedom  \
# Rank        1.000000 -0.992066 -0.697359 -0.754040 -0.743655 -0.537942
# Score      -0.992066  1.000000  0.697532  0.751268  0.742456  0.551258
# Support    -0.697359  0.697532  1.000000  0.579036  0.665765  0.365950
# GDP        -0.754040  0.751268  0.579036  1.000000  0.709518  0.384167
# Health     -0.743655  0.742456  0.665765  0.709518  1.000000  0.340745
# Freedom    -0.537942  0.551258  0.365950  0.384167  0.340745  1.000000
# Generosity -0.206222  0.223577  0.229671  0.071736  0.092768  0.358228
# Corruption -0.229450  0.253598 -0.122646  0.168577  0.131482  0.325643
# Year       -0.007768  0.007065  0.370395 -0.029253  0.130302  0.010353
#
#             Generosity  Corruption      Year
# Rank         -0.206222   -0.229450 -0.007768
# Score         0.223577    0.253598  0.007065
# Support       0.229671   -0.122646  0.370395
# GDP           0.071736    0.168577 -0.029253
# ...

# %%
fig_dims = (10, 6)
fig, ax = plt.subplots(figsize=fig_dims)
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# From the heatmap, we four variables has a strong correlation with the happiness score, they include:
# 1. `GDP` with a coefficient of `0.75`
# 2. `Health` with a coefficient of `0.74`
# 3. `Support` with a coefficient of `0.7`
# 4. `Freedom` with a coefficient of `0.55`
#
# There coefficient shows the degree to which they contribute to the happiness of a country, which `GDP` being the highest contributor, followed by `Health` etc..

# %% [markdown]
# **Secondly, a multiple linear regression model would help us quantify the contribution of each factor on the happiness of a country**

# %%
# MULTIPLE LR
X = df[['GDP', 'Health', 'Support','Freedom','Generosity','Corruption']]
y = df['Score']

import statsmodels.api as sm
X_sm = X = sm.add_constant(X)
model = sm.OLS(y,X_sm)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     419.8
# Date:                Thu, 04 Nov 2021   Prob (F-statistic):          1.43e-239
# Time:                        08:53:29   Log-Likelihood:                -637.20
# No. Observations:                 782   AIC:                             1288.
# Df Residuals:                     775   BIC:                             1321.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0430      0.073     28.040      0.000       1.900       2.186
# ...

# %% [markdown]
# The OLS Summary above reveals that all the features are significant positive predictors or contributors to nations'happiness, even at 99% confidence level, except for `Generosity` with a coefficient of `0.2281`. The most contributing factors or features are `Freedom(1.3574)`, `Corruption(1.2839)`, `Health	(1.0597)`, `GDP(0.9681)`, and `Support(0.9172)`.
#
# The result above means that a unit increase or change in people's freedom will result in an equaalent  increase in happiness by 1.3574 units. This applies to other too.

# %% [markdown]
# ## Question 3: Is overall happiness increasing or decreasing?

# %%
fig_dims = (10, 6)
fig, ax = plt.subplots(figsize=fig_dims)
plt.plot(df['Score'], linestyle = 'dotted')
plt.show()

# %% [markdown]
# From the line graph above, overall happiness is decreasing.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Cobclusively, we can see from the result of the analysis that the `GDP per capita`, `Health (life expectancy)`, `Freedom of the citizens` and `support` are strong contributors to the happiness of the citizens of a country.
